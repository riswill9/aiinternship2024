# %% [markdown]
# <a href="https://colab.research.google.com/github/riswill9/aiinternship2024/blob/main/Python_Starting_Working_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is pillow practice for AIIE 2024

# %% [markdown]
# #**Section 1**

# %%
from PIL import Image

# %%
from PIL import Image

my_image = Image.open("cat.jpg")
my_image.thumbnail((250,250))

my_image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=250x167>

# %%
# Print the height and width of the image
# TOCOMPLETE
h = my_image.height
print("Height of the image: ", h)
width = my_image.width
print("width of the image: ", width)
# Out:
# Height of the image:  167
# width of the image:  250

# %%
# Get the RGB of pixel
# TOCOMPLETE
pixel = my_image.getpixel((120, 60))
print("RGB of pixel : ", pixel)
print("R :", pixel[0])
print("R :", pixel[1])
print("R :", pixel[2])
# Out:
# RGB of pixel :  (248, 247, 250)
# R : 248
# R : 247
# R : 250

# %%
# What does this do? Add a comment
# likely deposits the color of the rgb parameters you choose(grey)
# TOCOMPLETE
my_image.putpixel((120,60), (120,120,120))

# %%
my_image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=250x167>

# %%
# all pixels are black

for x in range(my_image.width) :
  for y in range(my_image.height):
    pixel =  my_image.getpixel((x, y))
    my_image.putpixel((x,y), (0,0,0))

my_image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=250x167>

# %%
# Put all pixels for x and y even in black
# RGB = 0,0,0
my_image = Image.open("cat.jpg")
my_image.thumbnail((250,250))

for x in range(my_image.width) :
  for y in range(my_image.height):
    if x % 2 == 0 and y % 2 == 0:
      my_image.putpixel((x,y), (37,93,200))

my_image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=250x167>

# %%
my_image = Image.open("cat.jpg")
my_image.thumbnail((250,250))

my_image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=250x167>

# %%
# Pixel average
# TOCOMPLETE
def pixel_average(p):
   return int((p[0] + p[1] + p[2])/ 3)

# %%
# Replace bright pixels by grey pixels
# TOCOMPLETE

for x in range(my_image.width) :
  for y in range(my_image.height):
    pixel =  my_image.getpixel((x, y))
    m = pixel_average(pixel)
    if pixel_average(pixel) > 153:
      my_image.putpixel((x,y), (78, 120, pixel_average(pixel)) )


my_image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=250x167>

# %%
# adding a border surround the image

from PIL import Image

original_image = Image.open("cat.jpg")
original_image.thumbnail((250,250))
border_size = 8

new_width = original_image.width + 2*border_size
new_height = original_image.height + 2*border_size

bordered_img = Image.new('RGB', (new_width, new_height))
bordered_img.paste(my_image, (border_size, border_size))

bordered_img
# Out:
# <PIL.Image.Image image mode=RGB size=266x183>
